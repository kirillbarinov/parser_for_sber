# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# url = 'https://leave-russia.org/staying-companies?flt%5B147%5D%5Beq%5D%5B%5D=9057' main site 
url0 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=0'
url1 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=1'
url2 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=2'
url3 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=3'
url4 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=4'
url5 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=5'
url6 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=6'
url7 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=7'
url8 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=8'
url9 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=9'
url10 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=10'
url11 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=11'
url12 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=12'
url13 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=13'
url14 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=14'
url15 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=15'
url16 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=16'
url17 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=17'
url18 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=18'
url19 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=19'
url20 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=20'
url21 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=21'
url22 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=22'
url23 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=23'
url24 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=24'
url25 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=25'
url26 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=26'
url27 = 'https://leave-russia.org/?event=ajax&action=ArticleList.displayCache.1079&page=27'

# %%
# check for a connection 
response0 = requests.get(url0)
response1 = requests.get(url1)
response2 = requests.get(url2)
response3 = requests.get(url3)
response4 = requests.get(url4)
response5 = requests.get(url5)
response6 = requests.get(url6)
response7 = requests.get(url7)
response8 = requests.get(url8)
response9 = requests.get(url9)
response10 = requests.get(url10)
response11 = requests.get(url11)
response12 = requests.get(url12)
response13 = requests.get(url13)
response14 = requests.get(url14)

print('0 -', response0)
print('1 -', response1)
print('2 -', response2)
print('3 -', response3)
print('4 -', response4)
print('5 -', response5)
print('6 -', response6)
print('7 -', response7)
print('8 -', response8)
print('9 -', response9)
print('10 -', response10)
print('11 -', response11)
print('12 -', response12)
print('13 -', response13)
print('14 -', response14)

# <Response [200]> means correct
# Out:
# 0 - <Response [200]>
# 1 - <Response [200]>
# 2 - <Response [200]>
# 3 - <Response [200]>
# 4 - <Response [200]>
# 5 - <Response [200]>
# 6 - <Response [200]>
# 7 - <Response [200]>
# 8 - <Response [200]>
# 9 - <Response [200]>
# 10 - <Response [200]>
# 11 - <Response [200]>
# 12 - <Response [200]>
# 13 - <Response [200]>
# 14 - <Response [200]>

# %%
response15 = requests.get(url15)
response16 = requests.get(url16)
response17 = requests.get(url17)
response18 = requests.get(url18)
response19 = requests.get(url19)
response20 = requests.get(url20)
response21 = requests.get(url21)
response22 = requests.get(url22)
response23 = requests.get(url23)
response24 = requests.get(url24)
response25 = requests.get(url25)
response26 = requests.get(url26)
response27 = requests.get(url27)

print('15 -', response15)
print('16 -', response16)
print('17 -', response17)
print('18 -', response18)
print('19 -', response19)
print('20 -', response20)
print('21 -', response21)
print('22 -', response22)
print('23 -', response23)
print('24 -', response24)
print('25 -', response25)
print('26 -', response26)
print('27 -', response27)
# Out:
# 15 - <Response [200]>
# 16 - <Response [200]>
# 17 - <Response [200]>
# 18 - <Response [200]>
# 19 - <Response [200]>
# 20 - <Response [200]>
# 21 - <Response [200]>
# 22 - <Response [200]>
# 23 - <Response [200]>
# 24 - <Response [200]>
# 25 - <Response [200]>
# 26 - <Response [200]>
# 27 - <Response [200]>

# %% [markdown]
# # First 120 companies

# %%
bs0 = BeautifulSoup(response0.text, 'lxml')
bs1 = BeautifulSoup(response1.text, 'lxml')
bs2 = BeautifulSoup(response2.text, 'lxml')
bs3 = BeautifulSoup(response3.text, 'lxml')
bs4 = BeautifulSoup(response4.text, 'lxml')
bs5 = BeautifulSoup(response5.text, 'lxml')
bs6 = BeautifulSoup(response6.text, 'lxml')
bs7 = BeautifulSoup(response7.text, 'lxml')
bs8 = BeautifulSoup(response8.text, 'lxml')
bs9 = BeautifulSoup(response9.text, 'lxml')
bs10 = BeautifulSoup(response10.text, 'lxml')
bs11 = BeautifulSoup(response11.text, 'lxml')
bs12 = BeautifulSoup(response12.text, 'lxml')
bs13 = BeautifulSoup(response13.text, 'lxml')
bs14 = BeautifulSoup(response14.text, 'lxml')
bs15 = BeautifulSoup(response15.text, 'lxml')
bs16 = BeautifulSoup(response16.text, 'lxml')
bs17 = BeautifulSoup(response17.text, 'lxml')
bs18 = BeautifulSoup(response18.text, 'lxml')
bs19 = BeautifulSoup(response19.text, 'lxml')
bs20 = BeautifulSoup(response20.text, 'lxml')
bs21 = BeautifulSoup(response21.text, 'lxml')
bs22 = BeautifulSoup(response22.text, 'lxml')
bs23 = BeautifulSoup(response23.text, 'lxml')
bs24 = BeautifulSoup(response24.text, 'lxml')
bs25 = BeautifulSoup(response25.text, 'lxml')
bs26 = BeautifulSoup(response26.text, 'lxml')
bs27 = BeautifulSoup(response27.text, 'lxml')
#print(bs1.get_text())

# %% [markdown]
# Data 0

# %%
names0 = bs0.find_all('div', class_="annotation")
#print(names0)

discribtion0 = bs0.find_all('div', class_="decision")
#print(discribtion0)

status0 = bs0.find_all(class_="status")
#print(status0)

discribtion0_array = []
for tag in discribtion0:
    discribtion0_array.append(tag.text)
#print(discribtion0_array)

names0_array = []
for tag in names0:
    names0_array.append(tag.text)
#print(names0_array)

status0_array = []
for tag in status0:
    status0_array.append(tag.text)
#print(status0_array)

# to DataFrame
df0 = pd.DataFrame(np.column_stack([names0_array, discribtion0_array, status0_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 1

# %%
names1 = bs1.find_all('div', class_="annotation")
#print(names0)

discribtion1 = bs1.find_all('div', class_="decision")
#print(discribtion0)

status1 = bs1.find_all(class_="status")
#print(status0)

discribtion1_array = []
for tag in discribtion1:
    discribtion1_array.append(tag.text)

names1_array = []
for tag in names1:
    names1_array.append(tag.text)

status1_array = []
for tag in status1:
    status1_array.append(tag.text)

# to DataFrame
df1 = pd.DataFrame(np.column_stack([names1_array, discribtion1_array, status1_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 2

# %%
names2 = bs2.find_all('div', class_="annotation")
#print(names0)

discribtion2 = bs2.find_all('div', class_="decision")
#print(discribtion0)

status2 = bs2.find_all(class_="status")
#print(status0)

discribtion2_array = []
for tag in discribtion2:
    discribtion2_array.append(tag.text)

names2_array = []
for tag in names2:
    names2_array.append(tag.text)

status2_array = []
for tag in status2:
    status2_array.append(tag.text)

# to DataFrame
df2 = pd.DataFrame(np.column_stack([names2_array, discribtion2_array, status2_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 3

# %%
names3 = bs3.find_all('div', class_="annotation")
#print(names0)

discribtion3 = bs3.find_all('div', class_="decision")
#print(discribtion0)

status3 = bs3.find_all(class_="status")
#print(status0)

discribtion3_array = []
for tag in discribtion3:
    discribtion3_array.append(tag.text)

names3_array = []
for tag in names3:
    names3_array.append(tag.text)

status3_array = []
for tag in status3:
    status3_array.append(tag.text)

# to DataFrame
df3 = pd.DataFrame(np.column_stack([names3_array, discribtion3_array, status3_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 4

# %%
names4 = bs4.find_all('div', class_="annotation")
#print(names0)

discribtion4 = bs4.find_all('div', class_="decision")
#print(discribtion0)

status4 = bs4.find_all(class_="status")
#print(status0)

discribtion4_array = []
for tag in discribtion4:
    discribtion4_array.append(tag.text)

names4_array = []
for tag in names4:
    names4_array.append(tag.text)

status4_array = []
for tag in status4:
    status4_array.append(tag.text)

# to DataFrame
df4 = pd.DataFrame(np.column_stack([names4_array, discribtion4_array, status4_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 5

# %%
names5 = bs5.find_all('div', class_="annotation")
#print(names0)

discribtion5 = bs5.find_all('div', class_="decision")
#print(discribtion0)

status5 = bs5.find_all(class_="status")
#print(status0)

discribtion5_array = []
for tag in discribtion5:
    discribtion5_array.append(tag.text)

names5_array = []
for tag in names5:
    names5_array.append(tag.text)

status5_array = []
for tag in status5:
    status5_array.append(tag.text)

# to DataFrame
df5 = pd.DataFrame(np.column_stack([names5_array, discribtion5_array, status5_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 6

# %%
names6 = bs6.find_all('div', class_="annotation")
#print(names0)

discribtion6 = bs6.find_all('div', class_="decision")
#print(discribtion0)

status6 = bs6.find_all(class_="status")
#print(status0)

discribtion6_array = []
for tag in discribtion6:
    discribtion6_array.append(tag.text)

names6_array = []
for tag in names6:
    names6_array.append(tag.text)

status6_array = []
for tag in status6:
    status6_array.append(tag.text)

# to DataFrame
df6 = pd.DataFrame(np.column_stack([names6_array, discribtion6_array, status6_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 7

# %%
names7 = bs7.find_all('div', class_="annotation")
#print(names0)

discribtion7 = bs7.find_all('div', class_="decision")
#print(discribtion0)

status7 = bs7.find_all(class_="status")
#print(status0)

discribtion7_array = []
for tag in discribtion7:
    discribtion7_array.append(tag.text)

names7_array = []
for tag in names7:
    names7_array.append(tag.text)

status7_array = []
for tag in status7:
    status7_array.append(tag.text)

# to DataFrame
df7 = pd.DataFrame(np.column_stack([names7_array, discribtion7_array, status7_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 8

# %%
names8 = bs8.find_all('div', class_="annotation")

discribtion8 = bs8.find_all('div', class_="decision")

status8 = bs8.find_all(class_="status")

discribtion8_array = []
for tag in discribtion8:
    discribtion8_array.append(tag.text)

names8_array = []
for tag in names8:
    names8_array.append(tag.text)

status8_array = []
for tag in status8:
    status8_array.append(tag.text)

# to DataFrame
df8 = pd.DataFrame(np.column_stack([names8_array, discribtion8_array, status8_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 9

# %%
names9 = bs9.find_all('div', class_="annotation")

discribtion9 = bs9.find_all('div', class_="decision")

status9 = bs9.find_all(class_="status")

discribtion9_array = []
for tag in discribtion9:
    discribtion9_array.append(tag.text)

names9_array = []
for tag in names9:
    names9_array.append(tag.text)

status9_array = []
for tag in status9:
    status9_array.append(tag.text)

# to DataFrame
df9 = pd.DataFrame(np.column_stack([names9_array, discribtion9_array, status9_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 10

# %%
names10 = bs10.find_all('div', class_="annotation")

discribtion10 = bs10.find_all('div', class_="decision")

status10 = bs10.find_all(class_="status")

discribtion10_array = []
for tag in discribtion10:
    discribtion10_array.append(tag.text)

names10_array = []
for tag in names10:
    names10_array.append(tag.text)

status10_array = []
for tag in status10:
    status10_array.append(tag.text)

# to DataFrame
df10 = pd.DataFrame(np.column_stack([names10_array, discribtion10_array, status10_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 11

# %%
names11 = bs11.find_all('div', class_="annotation")

discribtion11 = bs11.find_all('div', class_="decision")

status11 = bs11.find_all(class_="status")

discribtion11_array = []
for tag in discribtion11:
    discribtion11_array.append(tag.text)

names11_array = []
for tag in names11:
    names11_array.append(tag.text)

status11_array = []
for tag in status11:
    status11_array.append(tag.text)

# to DataFrame
df11 = pd.DataFrame(np.column_stack([names11_array, discribtion11_array, status11_array]),
                   columns=['Company', 'Comment', 'Status'])

# %% [markdown]
# Data 12-27

# %%
names12 = bs12.find_all('div', class_="annotation")

discribtion12 = bs12.find_all('div', class_="decision")

status12 = bs12.find_all(class_="status")

discribtion12_array = []
for tag in discribtion12:
    discribtion12_array.append(tag.text)

names12_array = []
for tag in names12:
    names12_array.append(tag.text)

status12_array = []
for tag in status12:
    status12_array.append(tag.text)

# to DataFrame
df12 = pd.DataFrame(np.column_stack([names12_array, discribtion12_array, status12_array]),
                   columns=['Company', 'Comment', 'Status'])


names13 = bs13.find_all('div', class_="annotation")

discribtion13 = bs13.find_all('div', class_="decision")

status13 = bs13.find_all(class_="status")

discribtion13_array = []
for tag in discribtion13:
    discribtion13_array.append(tag.text)

names13_array = []
for tag in names13:
    names13_array.append(tag.text)

status13_array = []
for tag in status13:
    status13_array.append(tag.text)

# to DataFrame
df13 = pd.DataFrame(np.column_stack([names13_array, discribtion13_array, status13_array]),
                   columns=['Company', 'Comment', 'Status'])


names14 = bs14.find_all('div', class_="annotation")

discribtion14 = bs14.find_all('div', class_="decision")

status14 = bs14.find_all(class_="status")

discribtion14_array = []
for tag in discribtion14:
    discribtion14_array.append(tag.text)
discribtion14_array.insert(51, 'None')
    
names14_array = []
for tag in names14:
    names14_array.append(tag.text)

status14_array = []
for tag in status14:
    status14_array.append(tag.text)

# to DataFrame
df14 = pd.DataFrame(np.column_stack([names14_array, discribtion14_array, status14_array]),
                   columns=['Company', 'Comment', 'Status'])


names15 = bs15.find_all('div', class_="annotation")

discribtion15 = bs15.find_all('div', class_="decision")

status15 = bs15.find_all(class_="status")

discribtion15_array = []
for tag in discribtion15:
    discribtion15_array.append(tag.text)

names15_array = []
for tag in names15:
    names15_array.append(tag.text)

status15_array = []
for tag in status15:
    status15_array.append(tag.text)

# to DataFrame
df15 = pd.DataFrame(np.column_stack([names15_array, discribtion15_array, status15_array]),
                   columns=['Company', 'Comment', 'Status'])


names16 = bs16.find_all('div', class_="annotation")

discribtion16 = bs16.find_all('div', class_="decision")

status16 = bs16.find_all(class_="status")

discribtion16_array = []
for tag in discribtion16:
    discribtion16_array.append(tag.text)

names16_array = []
for tag in names16:
    names16_array.append(tag.text)

status16_array = []
for tag in status16:
    status16_array.append(tag.text)

# to DataFrame
df16 = pd.DataFrame(np.column_stack([names16_array, discribtion16_array, status16_array]),
                   columns=['Company', 'Comment', 'Status'])


names17 = bs17.find_all('div', class_="annotation")

discribtion17 = bs17.find_all('div', class_="decision")

status17 = bs17.find_all(class_="status")

discribtion17_array = []
for tag in discribtion17:
    discribtion17_array.append(tag.text)

names17_array = []
for tag in names17:
    names17_array.append(tag.text)

status17_array = []
for tag in status17:
    status17_array.append(tag.text)

# to DataFrame
df17 = pd.DataFrame(np.column_stack([names17_array, discribtion17_array, status17_array]),
                   columns=['Company', 'Comment', 'Status'])


names18 = bs18.find_all('div', class_="annotation")

discribtion18 = bs18.find_all('div', class_="decision")

status18 = bs18.find_all(class_="status")

discribtion18_array = []
for tag in discribtion18:
    discribtion18_array.append(tag.text)
discribtion18_array.insert(89, 'None')

names18_array = []
for tag in names18:
    names18_array.append(tag.text)

status18_array = []
for tag in status18:
    status18_array.append(tag.text)   

# to DataFrame
df18 = pd.DataFrame(np.column_stack([names18_array, discribtion18_array, status18_array]),
                   columns=['Company', 'Comment', 'Status'])


names19 = bs19.find_all('div', class_="annotation")

discribtion19 = bs19.find_all('div', class_="decision")

status19 = bs19.find_all(class_="status")

discribtion19_array = []
for tag in discribtion19:
    discribtion19_array.append(tag.text)

names19_array = []
for tag in names19:
    names19_array.append(tag.text)

status19_array = []
for tag in status19:
    status19_array.append(tag.text)

# to DataFrame
df19 = pd.DataFrame(np.column_stack([names19_array, discribtion19_array, status19_array]),
                   columns=['Company', 'Comment', 'Status'])


names20 = bs20.find_all('div', class_="annotation")

discribtion20 = bs20.find_all('div', class_="decision")

status20 = bs20.find_all(class_="status")

discribtion20_array = []
for tag in discribtion20:
    discribtion20_array.append(tag.text)

names20_array = []
for tag in names20:
    names20_array.append(tag.text)

status20_array = []
for tag in status20:
    status20_array.append(tag.text)

# to DataFrame
df20 = pd.DataFrame(np.column_stack([names20_array, discribtion20_array, status20_array]),
                   columns=['Company', 'Comment', 'Status'])


names21 = bs21.find_all('div', class_="annotation")

discribtion21 = bs21.find_all('div', class_="decision")

status21 = bs21.find_all(class_="status")

discribtion21_array = []
for tag in discribtion21:
    discribtion21_array.append(tag.text)

names21_array = []
for tag in names21:
    names21_array.append(tag.text)

status21_array = []
for tag in status21:
    status21_array.append(tag.text)

# to DataFrame
df21 = pd.DataFrame(np.column_stack([names21_array, discribtion21_array, status21_array]),
                   columns=['Company', 'Comment', 'Status'])


names22 = bs22.find_all('div', class_="annotation")

discribtion22 = bs22.find_all('div', class_="decision")

status22 = bs22.find_all(class_="status")

discribtion22_array = []
for tag in discribtion22:
    discribtion22_array.append(tag.text)
discribtion22_array.insert(110, 'None')
    
names22_array = []
for tag in names22:
    names22_array.append(tag.text)

status22_array = []
for tag in status22:
    status22_array.append(tag.text)

# to DataFrame
df22 = pd.DataFrame(np.column_stack([names22_array, discribtion22_array, status22_array]),
                   columns=['Company', 'Comment', 'Status'])


names23 = bs23.find_all('div', class_="annotation")

discribtion23 = bs23.find_all('div', class_="decision")

status23 = bs23.find_all(class_="status")

discribtion23_array = []
for tag in discribtion23:
    discribtion23_array.append(tag.text)

names23_array = []
for tag in names23:
    names23_array.append(tag.text)

status23_array = []
for tag in status23:
    status23_array.append(tag.text)

# to DataFrame
df23 = pd.DataFrame(np.column_stack([names23_array, discribtion23_array, status23_array]),
                   columns=['Company', 'Comment', 'Status'])


names24 = bs24.find_all('div', class_="annotation")

discribtion24 = bs24.find_all('div', class_="decision")

status24 = bs24.find_all(class_="status")

discribtion24_array = []
for tag in discribtion24:
    discribtion24_array.append(tag.text)

names24_array = []
for tag in names24:
    names24_array.append(tag.text)

status24_array = []
for tag in status24:
    status24_array.append(tag.text)

# to DataFrame
df24 = pd.DataFrame(np.column_stack([names24_array, discribtion24_array, status24_array]),
                   columns=['Company', 'Comment', 'Status'])


names25 = bs25.find_all('div', class_="annotation")

discribtion25 = bs25.find_all('div', class_="decision")

status25 = bs25.find_all(class_="status")

discribtion25_array = []
for tag in discribtion25:
    discribtion25_array.append(tag.text)
discribtion25_array.insert(42, 'None')

names25_array = []
for tag in names25:
    names25_array.append(tag.text)

status25_array = []
for tag in status25:
    status25_array.append(tag.text)

# to DataFrame
df25 = pd.DataFrame(np.column_stack([names25_array, discribtion25_array, status25_array]),
                   columns=['Company', 'Comment', 'Status'])


names26 = bs26.find_all('div', class_="annotation")

discribtion26 = bs26.find_all('div', class_="decision")

status26 = bs26.find_all(class_="status")

discribtion26_array = []
for tag in discribtion26:
    discribtion26_array.append(tag.text)

names26_array = []
for tag in names26:
    names26_array.append(tag.text)

status26_array = []
for tag in status26:
    status26_array.append(tag.text)

# to DataFrame
df26 = pd.DataFrame(np.column_stack([names26_array, discribtion26_array, status26_array]),
                   columns=['Company', 'Comment', 'Status'])


names27 = bs27.find_all('div', class_="annotation")

discribtion27 = bs27.find_all('div', class_="decision")

status27 = bs27.find_all(class_="status")

discribtion27_array = []
for tag in discribtion27:
    discribtion27_array.append(tag.text)

names27_array = []
for tag in names27:
    names27_array.append(tag.text)

status27_array = []
for tag in status27:
    status27_array.append(tag.text)

# to DataFrame
df27 = pd.DataFrame(np.column_stack([names27_array, discribtion27_array, status27_array]),
                   columns=['Company', 'Comment', 'Status'])

# %%
frames = [df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, 
         df12, df13, df14, df15, df16, df17, df18, df19, df20, df21,
         df22, df23, df24, df25, df26, df27]

result = pd.concat(frames)

# %%
def getTicker(company_name):
    try:
        yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
        user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
        params = {"q": company_name, "quotes_count": 1, "country": "United States"}

        res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
        data = res.json()

        company_code = data['quotes'][0]['symbol']
        return company_code
    except:
        company_code = 'None'
        return company_code

# %%
# Test
getTicker('Iskratel')
# Out:
# 'None'

# %%
res = result.iloc[:,0].values

# %%
tickers = []
for i in res:
    tickers.append(getTicker(i))

print(tickers)
# Out:
# ['PM', 'None', 'None', 'PEP', 'None', 'B4B.DE', 'NSRGY', 'BN.PA', 'MMC', 'PG', 'None', 'RBI.VI', 'BUD', 'MNDI.L', 'MDLZ', '6690.HK', 'UL', 'None', 'GMED', 'KMTUY', 'None', 'None', 'GELYF', 'None', 'None', 'None', 'None', 'KRK.WA', 'None', 'ISP.MI', 'None', 'TKTT.PA', 'None', 'None', 'None', 'WAB', 'None', 'TEVA', 'CPF.BK', 'None', 'IE.MI', 'BRRAY', 'BEKO13.OL', '1186.HK', 'None', 'HOLN.SW', 'None', 'GLAXO.NS', 'ZEP-USD', 'None', 'ROCK-B.CO', 'None', 'None', 'None', 'None', 'SMFG', '1810.HK', 'WFRD', 'None', 'None', 'MKTAY', 'None', '004800.KS', 'None', 'TYUM.CN', 'PVH', 'PXD', 'FMS', 'BABA', 'BDU.F', 'None', 'None', 'None', 'SHL.DE', 'None', 'None', 'ONTEX.BR', 'None', '0P00008FAK.F', '002415.SZ', '0P0000VKLL.BO', 'None', 'EOS', 'FRIGO.AT', 'None', 'None', '600309.SS', '000333.SZ', 'ALPLA.PA', 'EGIS', 'TWI', 'ARIS.MI', 'None', 'None', 'None', 'AWI', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'SUNPHARMA.NS', 'None', 'None', 'None', 'IGG.L', 'None', 'VVOS', 'None',
# ...

# %%
result.insert (loc=1 , column='Ticker', value=tickers)

# %%
from pathlib import Path  
filepath = Path('/Users/kirillbarinov/Downloads/out_fin1.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
result.to_csv(filepath)

# %% [markdown]
# # Наработки для улучшений

# %%
ur = 'https://finance.yahoo.com/quote/AAPL/key-statistics'
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
params = {"quotes_count": 1, "country": "United States"}

res = requests.get(ur, params=params, headers={'User-Agent': user_agent})

bsr = BeautifulSoup(res.text, 'lxml')

# %%
bsr.text
# Out:
# 'Apple Inc. (AAPL) Valuation Measures & Financial StatisticsHomeMailNewsFinanceSportsEntertainmentSearchMobileMore...Yahoo FinanceSearchSkip to NavigationSkip to Main ContentSkip to Related ContentSign inMailSign in to view your mailFinance HomeWatchlistsMy PortfolioMarketsNewsVideosScreenersPersonal FinanceCryptoIndustriesContact Us  \n                Advertisement\n  \n                Advertisement\nU.S. markets open in 2 hours 17 minutesS&P Futures4,521.50+14.00(+0.31%)Dow Futures34,609.00+59.00(+0.17%)Nasdaq Futures15,545.50+100.75(+0.65%)Russell 2000 Futures1,953.30+4.80(+0.25%)Crude Oil75.87+0.12(+0.16%)Gold1,964.80+3.10(+0.16%)  \n                Advertisement\n  \n                Advertisement\n  \n                Advertisement\n  \n                Advertisement\nApple Inc. (AAPL)NasdaqGS - NasdaqGS Real Time Price. Currency in USDFollow189.77+1.69 (+0.90%)At close:  04:00PM EDT190.62 +0.85 (+0.45%)Pre-Market: 07:12AM EDT  \n                Advertisement\nSummaryChartConversa
# ...

# %%
revenue = bsr.find_all("Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)")
print(revenue)
#class_=["Pos(r) Mt(10px)", "W(100%) Bdcl(c)", "Bxz(bb) H(36px) BdY Bdc($seperatorColor)", "Fw(500) Ta(end) Pstart(10px) Miw(60px)"]
# Out:
# []

# %%
class="BdY Bdc($seperatorColor) "
# Out:
#   File "<ipython-input-74-c3c48e7be4cb>", line 1
#     class="BdY Bdc($seperatorColor) "
#          ^
# SyntaxError: invalid syntax

# %%
gross = []
for i in range(len(tickers))
    if tickers[i] == 'None'
        gross.append('None')
    else
        gross.append(si.get_income_statement(tickers[i]))
